# %% [markdown]
# ### Exercise 3: Implementing SelectPercentile

# %%
import sys
import os
import numpy as np
import pandas as pd
sys.path.append("C:/Users/BeaBa/Documents/GitHub/si/src")

from si.data.dataset import Dataset
from si.io.csv_file import read_csv
from si.io.data_file import *
from si.base.transformer import Transformer
from si.statistics.f_classification import f_classification

# %%
Path= "C:/Users/BeaBa/Documents/GitHub/si/datasets/iris/"
iris = read_csv(Path + "iris.csv", sep=",", label=True)
iris.summary()
# Out:
#           feat_0    feat_1    feat_2    feat_3
# mean    5.843333  3.054000  3.758667  1.198667
# median  5.800000  3.000000  4.350000  1.300000
# min     4.300000  2.000000  1.000000  0.100000
# max     7.900000  4.400000  6.900000  2.500000
# var     0.681122  0.186751  3.092425  0.578532

# %%
selector = SelectPercentile(score_func=f_classification, percentile=30)
iris_fit = selector.fit_transform(iris)


print("Features selecionadas:", iris.features)
# Out:
# Features selecionadas: ['feat_0', 'feat_1', 'feat_2', 'feat_3']
